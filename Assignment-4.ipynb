# %% [markdown]
# ## Importing Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error

# %% [markdown]
# ## Relu Function

# %%
def relu(z):
    a = np.maximum(0,z)
    return a

# %% [markdown]
# ## Initialising parameters

# %%
def initialize_params(layer_sizes):
    params = {}
    for i in range(1, len(layer_sizes)):
        params['W' + str(i)] = np.random.randn(layer_sizes[i], layer_sizes[i-1])*0.01
        params['B' + str(i)] = np.random.randn(layer_sizes[i],1)*0.01
    return params

# %% [markdown]
# ## Forward Propagation

# %%
def forward_propagation(X_train, params):
    layers = len(params)//2
    values = {}
    for i in range(1, layers+1):
        if i==1:
            values['Z' + str(i)] = np.dot(params['W' + str(i)], X_train) + params['B' + str(i)]
            values['A' + str(i)] = relu(values['Z' + str(i)])
        else:
            values['Z' + str(i)] = np.dot(params['W' + str(i)], values['A' + str(i-1)]) + params['B' + str(i)]
            if i==layers:
                values['A' + str(i)] = values['Z' + str(i)]
            else:
                values['A' + str(i)] = relu(values['Z' + str(i)])
    return values

# %% [markdown]
# ## Computing Cost

# %%
def compute_cost(values, Y_train):
    layers = len(values)//2
    Y_pred = values['A' + str(layers)]
    cost = 1/(2*len(Y_train)) * np.sum(np.square(Y_pred - Y_train))
    return cost

# %% [markdown]
# ## Backward propagation

# %%
def backward_propagation(params, values, X_train, Y_train):
    layers = len(params)//2
    m = len(Y_train)
    grads = {}
    for i in range(layers,0,-1):
        if i==layers:
            dA = 1/m * (values['A' + str(i)] - Y_train)
            dZ = dA
        else:
            dA = np.dot(params['W' + str(i+1)].T, dZ)
            dZ = np.multiply(dA, np.where(values['A' + str(i)]>=0, 1, 0))
        if i==1:
            grads['W' + str(i)] = 1/m * np.dot(dZ, X_train.T)
            grads['B' + str(i)] = 1/m * np.sum(dZ, axis=1, keepdims=True)
        else:
            grads['W' + str(i)] = 1/m * np.dot(dZ,values['A' + str(i-1)].T)
            grads['B' + str(i)] = 1/m * np.sum(dZ, axis=1, keepdims=True)
    return grads

# %% [markdown]
# ## Updating parameters

# %%
def update_params(params, grads, learning_rate):
    layers = len(params)//2
    params_updated = {}
    for i in range(1,layers+1):
        params_updated['W' + str(i)] = params['W' + str(i)] - learning_rate * grads['W' + str(i)]
        params_updated['B' + str(i)] = params['B' + str(i)] - learning_rate * grads['B' + str(i)]
    return params_updated

# %% [markdown]
# ## Training model

# %%
def model(X_train, Y_train, layer_sizes, num_iters, learning_rate):
    params = initialize_params(layer_sizes)
    for i in range(num_iters):
        values = forward_propagation(X_train.T, params)
        cost = compute_cost(values, Y_train.T)
        grads = backward_propagation(params, values,X_train.T, Y_train.T)
        params = update_params(params, grads, learning_rate)
        print('Cost at iteration ' + str(i+1) + ' = ' + str(cost) + '\n')
    return params

# %% [markdown]
# ## Computing accuracy

# %%
def compute_accuracy(X_train, X_test, Y_train, Y_test, params):
    values_train = forward_propagation(X_train.T, params)
    values_test = forward_propagation(X_test.T, params)
    train_acc = np.sqrt(mean_squared_error(Y_train, values_train['A' + str(len(layer_sizes)-1)].T))
    test_acc = np.sqrt(mean_squared_error(Y_test, values_test['A' + str(len(layer_sizes)-1)].T))
    return train_acc, test_acc

# %% [markdown]
# ## Predict

# %%
def predict(X, params):
    values = forward_propagation(X.T, params)
    predictions = values['A' + str(len(values)//2)].T
    return predictions

# %% [markdown]
# ## Implementation

# %%
df = pd.concat(pd.read_excel("data.xlsx", sheet_name=None), ignore_index=True)
X = df[['AT','V', 'AP', 'RH']].values
Y=df['PE'].values
X_train,X_test,Y_train,Y_test = train_test_split(X, Y, test_size = 0.2)           
layer_sizes = [4, 2, 1]                                                       
num_iters = 2000                                                                  
learning_rate = 0.05                                                              
params = model(X_train, Y_train, layer_sizes, num_iters, learning_rate)           
train_acc, test_acc = compute_accuracy(X_train, X_test, Y_train, Y_test, params)  
print('Root Mean Squared Error on Training Data = ' + str(train_acc))
print('Root Mean Squared Error on Test Data = ' + str(test_acc))
# Out:
# Cost at iteration 1 = 103176.96815772529
#
# Cost at iteration 2 = 102899.51833180006
#
# Cost at iteration 3 = 102191.48503006337
#
# Cost at iteration 4 = 100392.39498881163
#
# Cost at iteration 5 = 95905.40159044981
#
# Cost at iteration 6 = 85244.37123293728
#
# Cost at iteration 7 = 62858.72198876978
#
# Cost at iteration 8 = 28373.061306133342
#
# Cost at iteration 9 = 3257.7290021236395
#
# Cost at iteration 10 = 135.88568036300512
#
# Cost at iteration 11 = 128.35000124074932
#
# Cost at iteration 12 = 127.97025780262852
#
# Cost at iteration 13 = 127.92513703477475
#
# Cost at iteration 14 = 127.8942623574245
#
# Cost at iteration 15 = 127.86401529228655
#
# Cost at iteration 16 = 127.83380428202844
#
# Cost at iteration 17 = 127.8036037373281
#
# Cost at iteration 18 = 127.77341254257304
#
# Cost at iteration 19 = 127.74323064150265
#
# Cost at iteration 20 = 127.7130580237093
#
# Cost at iteration 21 = 127.6828946807794
#
# Cost at iteration 22 = 127.65274060439543
#
# Cost at iteration 23 = 127.62259578625334
#
# Cost at iteration 24 = 127.59246021805927
#
# Cost at iteration 25 = 127.56233389152935
#
# Cost at iteration 26 = 127.53221679838956
#
# Cost at iteration 27 = 127.50210893037588
#
# Cost at iteration 28 = 127.47201027923414
#
# Cost at iteration 29 = 127.44192083672004
#
# Cost at iteration 30 = 127.41184059459923
#
# Cost at iteration 31 = 127.38176954464713
#
# Cost at iteration 32 = 127.35170767864909
#
# Cost at iteration 33 = 127.32165498840028
#
# Cost at iteration 34 = 127.29161146570564
#
# Cost at iteration 35 = 127.26157710238004
#
# Cost at iteration 36 = 127.23155189024796
#
# Cost at iteration 37 = 127.20153582114389
#
# Cost at iteration 38 = 127.17152888691189
#
# Cost at iteration 39 = 127.14153107940588
#
# Cost at iteration 40 = 127.11154239048955
#
# Cost at iteration 41 = 127.08156281203622
#
# Cost at iteration 42 = 127.05159233592907
#
# Cost at iteration 43 = 127.02163095406085
#
# Cost at iteration 44 = 126.99167865833408
#
# Cost at iteration 45 = 126.96173544066097
#
# Cost at iteration 46 = 126.93180129296337
#
# Cost at iteration 47 = 126.90187620717278
#
# Cost at iteration 48 = 126.87196017523031
#
# Cost at iteration 49 = 126.84205318908684
#
# Cost at iteration 50 = 126.81215524070272
#
# Cost at iteration 51 = 126.78226632204796
#
# Cost at iteration 52 = 126.75238642510217
#
# Cost at iteration 53 = 126.7225155418545
#
# Cost at iteration 54 = 126.69265366430378
#
# Cost at iteration 55 = 126.66280078445824
#
# Cost at iteration 56 = 126.6329568943357
#
# Cost at iteration 57 = 126.60312198596363
#
# Cost at iteration 58 = 126.57329605137883
#
# Cost at iteration 59 = 126.54347908262775
#
# Cost at iteration 60 = 126.51367107176625
#
# Cost at iteration 61 = 126.48387201085973
#
# Cost at iteration 62 = 126.45408189198297
#
# Cost at iteration 63 = 126.42430070722028
#
# Cost at iteration 64 = 126.39452844866543
#
# Cost at iteration 65 = 126.36476510842152
#
# Cost at iteration 66 = 126.3350106786012
#
# Cost at iteration 67 = 126.30526515132635
#
# Cost at iteration 68 = 126.27552851872845
#
# Cost at iteration 69 = 126.24580077294817
#
# Cost at iteration 70 = 126.21608190613567
#
# Cost at iteration 71 = 126.18637191045046
#
# Cost at iteration 72 = 126.15667077806128
#
# Cost at iteration 73 = 126.12697850114637
#
# Cost at iteration 74 = 126.09729507189317
#
# Cost at iteration 75 = 126.06762048249843
#
# Cost at iteration 76 = 126.03795472516828
#
# Cost at iteration 77 = 126.00829779211803
#
# Cost at iteration 78 = 125.97864967557234
#
# Cost at iteration 79 = 125.94901036776504
#
# Cost at iteration 80 = 125.91937986093936
#
# Cost at iteration 81 = 125.88975814734762
#
# Cost at iteration 82 = 125.8601452192514
#
# Cost at iteration 83 = 125.83054106892149
#
# Cost at iteration 84 = 125.80094568863788
#
# Cost at iteration 85 = 125.77135907068978
#
# Cost at iteration 86 = 125.74178120737562
#
# Cost at iteration 87 = 125.71221209100277
#
# Cost at iteration 88 = 125.682651713888
#
# Cost at iteration 89 = 125.65310006835715
#
# Cost at iteration 90 = 125.62355714674504
#
# Cost at iteration 91 = 125.59402294139586
#
# Cost at iteration 92 = 125.56449744466265
#
# Cost at iteration 93 = 125.53498064890769
#
# Cost at iteration 94 = 125.50547254650238
#
# Cost at iteration 95 = 125.47597312982698
#
# Cost at iteration 96 = 125.44648239127108
#
# Cost at iteration 97 = 125.41700032323311
#
# Cost at iteration 98 = 125.38752691812059
#
# Cost at iteration 99 = 125.35806216835005
#
# Cost at iteration 100 = 125.32860606634709
#
# Cost at iteration 101 = 125.29915860454625
#
# Cost at iteration 102 = 125.26971977539104
#
# Cost at iteration 103 = 125.24028957133405
#
# Cost at iteration 104 = 125.2108679848367
#
# Cost at iteration 105 = 125.18145500836941
#
# Cost at iteration 106 = 125.1520506344116
#
# Cost at iteration 107 = 125.12265485545153
#
# Cost at iteration 108 = 125.09326766398641
#
# Cost at iteration 109 = 125.0638890525224
#
# Cost at iteration 110 = 125.03451901357445
#
# Cost at iteration 111 = 125.00515753966653
#
# Cost at iteration 112 = 124.97580462333134
#
# Cost at iteration 113 = 124.94646025711052
#
# Cost at iteration 114 = 124.91712443355455
#
# Cost at iteration 115 = 124.88779714522276
#
# Cost at iteration 116 = 124.85847838468327
#
# Cost at iteration 117 = 124.82916814451298
#
# Cost at iteration 118 = 124.7998664172977
#
# Cost at iteration 119 = 124.77057319563198
#
# Cost at iteration 120 = 124.7412884721191
#
# Cost at iteration 121 = 124.71201223937119
#
# Cost at iteration 122 = 124.68274449000906
#
# Cost at iteration 123 = 124.65348521666233
#
# Cost at iteration 124 = 124.62423441196933
#
# Cost at iteration 125 = 124.5949920685771
#
# Cost at iteration 126 = 124.56575817914143
#
# Cost at iteration 127 = 124.53653273632678
#
# Cost at iteration 128 = 124.50731573280628
#
# Cost at iteration 129 = 124.4781071612618
#
# Cost at iteration 130 = 124.44890701438385
#
# Cost at iteration 131 = 124.41971528487156
#
# Cost at iteration 132 = 124.3905319654328
#
# Cost at iteration 133 = 124.36135704878394
#
# Cost at iteration 134 = 124.3321905276501
#
# Cost at iteration 135 = 124.30303239476494
#
# Cost at iteration 136 = 124.27388264287079
#
# Cost at iteration 137 = 124.24474126471847
#
# Cost at iteration 138 = 124.21560825306746
#
# Cost at iteration 139 = 124.18648360068578
#
# Cost at iteration 140 = 124.15736730035003
#
# Cost at iteration 141 = 124.12825934484532
#
# Cost at iteration 142 = 124.09915972696531
#
# Cost at iteration 143 = 124.07006843951226
#
# Cost at iteration 144 = 124.0409854752968
#
# Cost at iteration 145 = 124.01191082713815
#
# Cost at iteration 146 = 123.98284448786407
#
# Cost at iteration 147 = 123.95378645031073
#
# Cost at iteration 148 = 123.9247367073228
#
# Cost at iteration 149 = 123.8956952517534
#
# Cost at iteration 150 = 123.86666207646405
#
# Cost at iteration 151 = 123.83763717432485
#
# Cost at iteration 152 = 123.80862053821411
#
# Cost at iteration 153 = 123.77961216101887
#
# Cost at iteration 154 = 123.75061203563428
#
# Cost at iteration 155 = 123.72162015496406
#
# Cost at iteration 156 = 123.69263651192023
#
# Cost at iteration 157 = 123.66366109942321
#
# Cost at iteration 158 = 123.63469391040181
#
# Cost at iteration 159 = 123.60573493779319
#
# Cost at iteration 160 = 123.57678417454282
#
# Cost at iteration 161 = 123.54784161360458
#
# Cost at iteration 162 = 123.51890724794056
#
# Cost at iteration 163 = 123.48998107052121
#
# Cost at iteration 164 = 123.46106307432535
#
# Cost at iteration 165 = 123.43215325234004
#
# Cost at iteration 166 = 123.40325159756061
#
# Cost at iteration 167 = 123.37435810299061
#
# Cost at iteration 168 = 123.34547276164197
#
# Cost at iteration 169 = 123.31659556653483
#
# Cost at iteration 170 = 123.28772651069747
#
# Cost at iteration 171 = 123.25886558716658
#
# Cost at iteration 172 = 123.2300127889869
#
# Cost at iteration 173 = 123.20116810921148
#
# Cost at iteration 174 = 123.1723315409015
#
# Cost at iteration 175 = 123.1435030771264
#
# Cost at iteration 176 = 123.11468271096375
#
# Cost at iteration 177 = 123.08587043549933
#
# Cost at iteration 178 = 123.05706624382704
#
# Cost at iteration 179 = 123.0282701290489
#
# Cost at iteration 180 = 122.99948208427514
#
# Cost at iteration 181 = 122.97070210262407
#
# Cost at iteration 182 = 122.94193017722212
#
# Cost at iteration 183 = 122.91316630120387
#
# Cost at iteration 184 = 122.8844104677119
#
# Cost at iteration 185 = 122.855662669897
#
# Cost at iteration 186 = 122.82692290091795
#
# Cost at iteration 187 = 122.79819115394162
#
# Cost at iteration 188 = 122.76946742214291
#
# Cost at iteration 189 = 122.74075169870486
#
# Cost at iteration 190 = 122.71204397681844
#
# Cost at iteration 191 = 122.68334424968266
#
# Cost at iteration 192 = 122.65465251050462
#
# Cost at iteration 193 = 122.62596875249939
#
# Cost at iteration 194 = 122.59729296888999
#
# Cost at iteration 195 = 122.56862515290744
#
# Cost at iteration 196 = 122.53996529779083
#
# Cost at iteration 197 = 122.51131339678707
#
# Cost at iteration 198 = 122.48266944315115
#
# Cost at iteration 199 = 122.454033430146
#
# Cost at iteration 200 = 122.42540535104234
# Cost at iteration 201 = 122.396785199119
#
# Cost at iteration 202 = 122.36817296766262
#
# Cost at iteration 203 = 122.33956864996777
#
# Cost at iteration 204 = 122.31097223933698
#
# Cost at iteration 205 = 122.28238372908059
#
# Cost at iteration 206 = 122.25380311251682
#
# Cost at iteration 207 = 122.22523038297177
#
# Cost at iteration 208 = 122.19666553377947
#
# Cost at iteration 209 = 122.16810855828169
#
# Cost at iteration 210 = 122.13955944982811
#
# Cost at iteration 211 = 122.11101820177623
#
# Cost at iteration 212 = 122.0824848074913
#
# Cost at iteration 213 = 122.05395926034653
#
# Cost at iteration 214 = 122.02544155372273
#
# Cost at iteration 215 = 121.99693168100873
#
# Cost at iteration 216 = 121.968429635601
#
# Cost at iteration 217 = 121.9399354109037
#
# Cost at iteration 218 = 121.91144900032894
#
# Cost at iteration 219 = 121.88297039729652
#
# Cost at iteration 220 = 121.85449959523395
#
# Cost at iteration 221 = 121.82603658757645
#
# Cost at iteration 222 = 121.79758136776702
#
# Cost at iteration 223 = 121.76913392925637
#
# Cost at iteration 224 = 121.74069426550291
#
# Cost at iteration 225 = 121.71226236997273
#
# Cost at iteration 226 = 121.6838382361396
#
# Cost at iteration 227 = 121.65542185748498
#
# Cost at iteration 228 = 121.62701322749804
#
# Cost at iteration 229 = 121.59861233967555
#
# Cost at iteration 230 = 121.57021918752196
#
# Cost at iteration 231 = 121.54183376454928
#
# Cost at iteration 232 = 121.51345606427732
#
# Cost at iteration 233 = 121.48508608023337
#
# Cost at iteration 234 = 121.45672380595232
#
# Cost at iteration 235 = 121.42836923497677
#
# Cost at iteration 236 = 121.40002236085685
#
# Cost at iteration 237 = 121.37168317715027
#
# Cost at iteration 238 = 121.34335167742235
#
# Cost at iteration 239 = 121.3150278552459
#
# Cost at iteration 240 = 121.28671170420138
#
# Cost at iteration 241 = 121.25840321787673
#
# Cost at iteration 242 = 121.23010238986748
#
# Cost at iteration 243 = 121.20180921377664
#
# Cost at iteration 244 = 121.17352368321477
#
# Cost at iteration 245 = 121.14524579179988
#
# Cost at iteration 246 = 121.1169755331576
#
# Cost at iteration 247 = 121.088712900921
#
# Cost at iteration 248 = 121.06045788873053
#
# Cost at iteration 249 = 121.03221049023425
#
# Cost at iteration 250 = 121.00397069908763
#
# Cost at iteration 251 = 120.9757385089536
#
# Cost at iteration 252 = 120.94751391350258
#
# Cost at iteration 253 = 120.91929690641228
#
# Cost at iteration 254 = 120.89108748136805
#
# Cost at iteration 255 = 120.86288563206247
#
# Cost at iteration 256 = 120.83469135219573
#
# Cost at iteration 257 = 120.80650463547519
#
# Cost at iteration 258 = 120.77832547561579
#
# Cost at iteration 259 = 120.75015386633974
#
# Cost at iteration 260 = 120.72198980137668
#
# Cost at iteration 261 = 120.69383327446364
#
# Cost at iteration 262 = 120.66568427934496
#
# Cost at iteration 263 = 120.63754280977228
#
# Cost at iteration 264 = 120.60940885950474
#
# Cost at iteration 265 = 120.58128242230862
#
# Cost at iteration 266 = 120.55316349195766
#
# Cost at iteration 267 = 120.52505206223285
#
# Cost at iteration 268 = 120.49694812692253
#
# Cost at iteration 269 = 120.46885167982227
#
# Cost at iteration 270 = 120.44076271473497
#
# Cost at iteration 271 = 120.4126812254708
#
# Cost at iteration 272 = 120.38460720584719
#
# Cost at iteration 273 = 120.35654064968891
#
# Cost at iteration 274 = 120.32848155082782
#
# Cost at iteration 275 = 120.30042990310316
#
# Cost at iteration 276 = 120.27238570036134
#
# Cost at iteration 277 = 120.24434893645605
#
# Cost at iteration 278 = 120.21631960524807
#
# Cost at iteration 279 = 120.18829770060563
#
# Cost at iteration 280 = 120.1602832164039
#
# Cost at iteration 281 = 120.13227614652537
#
# Cost at iteration 282 = 120.10427648485968
#
# Cost at iteration 283 = 120.07628422530371
#
# Cost at iteration 284 = 120.04829936176138
#
# Cost at iteration 285 = 120.02032188814395
#
# Cost at iteration 286 = 119.99235179836964
#
# Cost at iteration 287 = 119.9643890863639
#
# Cost at iteration 288 = 119.93643374605925
#
# Cost at iteration 289 = 119.90848577139546
#
# Cost at iteration 290 = 119.88054515631933
#
# Cost at iteration 291 = 119.85261189478473
#
# Cost at iteration 292 = 119.82468598075273
#
# Cost at iteration 293 = 119.79676740819139
#
# Cost at iteration 294 = 119.76885617107583
#
# Cost at iteration 295 = 119.74095226338844
#
# Cost at iteration 296 = 119.71305567911841
#
# Cost at iteration 297 = 119.68516641226218
#
# Cost at iteration 298 = 119.6572844568231
#
# Cost at iteration 299 = 119.62940980681175
#
# Cost at iteration 300 = 119.60154245624547
#
# Cost at iteration 301 = 119.57368239914888
#
# Cost at iteration 302 = 119.54582962955348
#
# Cost at iteration 303 = 119.51798414149772
#
# Cost at iteration 304 = 119.49014592902725
#
# Cost at iteration 305 = 119.46231498619444
#
# Cost at iteration 306 = 119.43449130705889
#
# Cost at iteration 307 = 119.40667488568705
#
# Cost at iteration 308 = 119.37886571615232
#
# Cost at iteration 309 = 119.3510637925351
#
# Cost at iteration 310 = 119.32326910892272
#
# Cost at iteration 311 = 119.29548165940942
#
# Cost at iteration 312 = 119.26770143809648
#
# Cost at iteration 313 = 119.23992843909195
#
# Cost at iteration 314 = 119.21216265651093
#
# Cost at iteration 315 = 119.18440408447535
#
# Cost at iteration 316 = 119.15665271711401
#
# Cost at iteration 317 = 119.1289085485627
#
# Cost at iteration 318 = 119.10117157296402
#
# Cost at iteration 319 = 119.07344178446746
#
# Cost at iteration 320 = 119.04571917722937
#
# Cost at iteration 321 = 119.01800374541301
#
# Cost at iteration 322 = 118.99029548318839
#
# Cost at iteration 323 = 118.96259438473247
#
# Cost at iteration 324 = 118.93490044422894
#
# Cost at iteration 325 = 118.90721365586845
#
# Cost at iteration 326 = 118.87953401384827
#
# Cost at iteration 327 = 118.85186151237272
#
# Cost at iteration 328 = 118.82419614565272
#
# Cost at iteration 329 = 118.7965379079061
#
# Cost at iteration 330 = 118.76888679335738
#
# Cost at iteration 331 = 118.74124279623801
#
# Cost at iteration 332 = 118.71360591078606
#
# Cost at iteration 333 = 118.68597613124638
#
# Cost at iteration 334 = 118.65835345187074
#
# Cost at iteration 335 = 118.63073786691739
#
# Cost at iteration 336 = 118.60312937065154
#
# Cost at iteration 337 = 118.57552795734507
#
# Cost at iteration 338 = 118.54793362127647
#
# Cost at iteration 339 = 118.52034635673115
#
# Cost at iteration 340 = 118.49276615800103
#
# Cost at iteration 341 = 118.46519301938481
#
# Cost at iteration 342 = 118.43762693518798
#
# Cost at iteration 343 = 118.41006789972255
#
# Cost at iteration 344 = 118.38251590730725
#
# Cost at iteration 345 = 118.3549709522676
#
# Cost at iteration 346 = 118.3274330289356
#
# Cost at iteration 347 = 118.29990213165006
#
# Cost at iteration 348 = 118.27237825475623
#
# Cost at iteration 349 = 118.24486139260634
#
# Cost at iteration 350 = 118.21735153955889
#
# Cost at iteration 351 = 118.18984868997919
#
# Cost at iteration 352 = 118.16235283823912
#
# Cost at iteration 353 = 118.13486397871718
#
# Cost at iteration 354 = 118.10738210579848
#
# Cost at iteration 355 = 118.07990721387468
#
# Cost at iteration 356 = 118.0524392973441
#
# Cost at iteration 357 = 118.0249783506115
#
# Cost at iteration 358 = 117.99752436808839
#
# Cost at iteration 359 = 117.97007734419267
#
# Cost at iteration 360 = 117.94263727334892
#
# Cost at iteration 361 = 117.9152041499882
#
# Cost at iteration 362 = 117.8877779685481
#
# Cost at iteration 363 = 117.86035872347281
#
# Cost at iteration 364 = 117.83294640921295
#
# Cost at iteration 365 = 117.80554102022576
#
# Cost at iteration 366 = 117.7781425509749
#
# Cost at iteration 367 = 117.75075099593055
#
# Cost at iteration 368 = 117.72336634956939
#
# Cost at iteration 369 = 117.69598860637468
#
# Cost at iteration 370 = 117.66861776083591
#
# Cost at iteration 371 = 117.64125380744939
#
# Cost at iteration 372 = 117.6138967407176
#
# Cost at iteration 373 = 117.5865465551496
#
# Cost at iteration 374 = 117.55920324526083
#
# Cost at iteration 375 = 117.53186680557332
#
# Cost at iteration 376 = 117.5045372306154
#
# Cost at iteration 377 = 117.47721451492185
#
# Cost at iteration 378 = 117.4498986530339
#
# Cost at iteration 379 = 117.42258963949912
#
# Cost at iteration 380 = 117.39528746887167
#
# Cost at iteration 381 = 117.36799213571183
#
# Cost at iteration 382 = 117.34070363458652
#
# Cost at iteration 383 = 117.31342196006888
#
# Cost at iteration 384 = 117.28614710673855
#
# Cost at iteration 385 = 117.2588790691814
#
# Cost at iteration 386 = 117.23161784198977
#
# Cost at iteration 387 = 117.20436341976236
#
# Cost at iteration 388 = 117.17711579710411
#
# Cost at iteration 389 = 117.1498749686264
#
# Cost at iteration 390 = 117.12264092894691
#
# Cost at iteration 391 = 117.09541367268965
#
# Cost at iteration 392 = 117.06819319448489
#
# Cost at iteration 393 = 117.04097948896933
#
# Cost at iteration 394 = 117.01377255078589
#
# Cost at iteration 395 = 116.98657237458376
#
# Cost at iteration 396 = 116.95937895501847
#
# Cost at iteration 397 = 116.93219228675181
#
# Cost at iteration 398 = 116.90501236445193
#
# Cost at iteration 399 = 116.87783918279315
#
# Cost at iteration 400 = 116.85067273645598
#
# Cost at iteration 401 = 116.82351302012738
#
# Cost at iteration 402 = 116.79636002850044
#
# Cost at iteration 403 = 116.76921375627451
#
# Cost at iteration 404 = 116.7420741981551
#
# Cost at iteration 405 = 116.7149413488541
#
# Cost at iteration 406 = 116.68781520308947
#
# Cost at iteration 407 = 116.66069575558545
#
# Cost at iteration 408 = 116.63358300107255
#
# Cost at iteration 409 = 116.60647693428729
#
# Cost at iteration 410 = 116.57937754997259
#
# Cost at iteration 411 = 116.55228484287738
#
# Cost at iteration 412 = 116.5251988077569
#
# Cost at iteration 413 = 116.49811943937246
#
# Cost at iteration 414 = 116.47104673249164
#
# Cost at iteration 415 = 116.44398068188805
#
# Cost at iteration 416 = 116.41692128234155
#
# Cost at iteration 417 = 116.38986852863805
#
# Cost at iteration 418 = 116.36282241556968
#
# Cost at iteration 419 = 116.33578293793472
#
# Cost at iteration 420 = 116.3087500905374
#
# Cost at iteration 421 = 116.2817238681883
#
# Cost at iteration 422 = 116.25470426570392
#
# Cost at iteration 423 = 116.2276912779069
#
# Cost at iteration 424 = 116.20068489962607
#
# Cost at iteration 425 = 116.17368512569627
#
# Cost at iteration 426 = 116.14669195095837
#
# Cost at iteration 427 = 116.11970537025942
#
# Cost at iteration 428 = 116.09272537845251
#
# Cost at iteration 429 = 116.06575197039672
#
# Cost at iteration 430 = 116.03878514095724
#
# Cost at iteration 431 = 116.01182488500534
#
# Cost at iteration 432 = 115.98487119741824
#
# Cost at iteration 433 = 115.95792407307928
#
# Cost at iteration 434 = 115.93098350687777
#
# Cost at iteration 435 = 115.90404949370902
#
# Cost at iteration 436 = 115.87712202847447
#
# Cost at iteration 437 = 115.8502011060814
#
# Cost at iteration 438 = 115.82328672144321
#
# Cost at iteration 439 = 115.79637886947927
#
# Cost at iteration 440 = 115.7694775451149
#
# Cost at iteration 441 = 115.74258274328147
#
# Cost at iteration 442 = 115.71569445891622
#
# Cost at iteration 443 = 115.6888126869624
#
# Cost at iteration 444 = 115.66193742236928
#
# Cost at iteration 445 = 115.63506866009205
#
# Cost at iteration 446 = 115.60820639509174
#
# Cost at iteration 447 = 115.58135062233549
#
# Cost at iteration 448 = 115.55450133679624
#
# Cost at iteration 449 = 115.52765853345298
#
# Cost at iteration 450 = 115.50082220729047
#
# Cost at iteration 451 = 115.4739923532995
#
# Cost at iteration 452 = 115.44716896647674
#
# Cost at iteration 453 = 115.42035204182471
#
# Cost at iteration 454 = 115.39354157435193
#
# Cost at iteration 455 = 115.36673755907269
#
# Cost at iteration 456 = 115.3399399910072
#
# Cost at iteration 457 = 115.3131488651816
#
# Cost at iteration 458 = 115.28636417662784
#
# Cost at iteration 459 = 115.25958592038376
#
# Cost at iteration 460 = 115.23281409149298
#
# Cost at iteration 461 = 115.20604868500513
#
# Cost at iteration 462 = 115.17928969597551
#
# Cost at iteration 463 = 115.15253711946534
#
# Cost at iteration 464 = 115.12579095054167
#
# Cost at iteration 465 = 115.09905118427737
#
# Cost at iteration 466 = 115.07231781575106
#
# Cost at iteration 467 = 115.04559084004732
#
# Cost at iteration 468 = 115.01887025225638
#
# Cost at iteration 469 = 114.99215604747434
#
# Cost at iteration 470 = 114.9654482208031
#
# Cost at iteration 471 = 114.93874676735028
#
# Cost at iteration 472 = 114.9120516822294
#
# Cost at iteration 473 = 114.8853629605596
#
# Cost at iteration 474 = 114.85868059746589
#
# Cost at iteration 475 = 114.83200458807903
#
# Cost at iteration 476 = 114.80533492753548
#
# Cost at iteration 477 = 114.77867161097753
#
# Cost at iteration 478 = 114.75201463355312
#
# Cost at iteration 479 = 114.72536399041601
#
# Cost at iteration 480 = 114.69871967672556
#
# Cost at iteration 481 = 114.67208168764705
#
# Cost at iteration 482 = 114.6454500183513
#
# Cost at iteration 483 = 114.61882466401494
#
# Cost at iteration 484 = 114.59220561982019
#
# Cost at iteration 485 = 114.56559288095512
#
# Cost at iteration 486 = 114.53898644261342
#
# Cost at iteration 487 = 114.5123862999944
#
# Cost at iteration 488 = 114.48579244830316
#
# Cost at iteration 489 = 114.4592048827504
#
# Cost at iteration 490 = 114.43262359855251
#
# Cost at iteration 491 = 114.40604859093153
#
# Cost at iteration 492 = 114.37947985511522
#
# Cost at iteration 493 = 114.35291738633683
# Cost at iteration 494 = 114.32636117983543
#
# Cost at iteration 495 = 114.29981123085562
#
# Cost at iteration 496 = 114.2732675346477
#
# Cost at iteration 497 = 114.24673008646745
#
# Cost at iteration 498 = 114.22019888157647
#
# Cost at iteration 499 = 114.19367391524186
#
# Cost at iteration 500 = 114.16715518273625
#
# Cost at iteration 501 = 114.14064267933807
#
# Cost at iteration 502 = 114.11413640033115
#
# Cost at iteration 503 = 114.08763634100502
#
# Cost at iteration 504 = 114.06114249665471
#
# Cost at iteration 505 = 114.03465486258098
#
# Cost at iteration 506 = 114.00817343408997
#
# Cost at iteration 507 = 113.98169820649345
#
# Cost at iteration 508 = 113.9552291751088
#
# Cost at iteration 509 = 113.92876633525896
#
# Cost at iteration 510 = 113.90230968227227
#
# Cost at iteration 511 = 113.87585921148278
#
# Cost at iteration 512 = 113.84941491822998
#
# Cost at iteration 513 = 113.82297679785893
#
# Cost at iteration 514 = 113.79654484572016
#
# Cost at iteration 515 = 113.77011905716978
#
# Cost at iteration 516 = 113.74369942756934
#
# Cost at iteration 517 = 113.71728595228598
#
# Cost at iteration 518 = 113.69087862669228
#
# Cost at iteration 519 = 113.66447744616629
#
# Cost at iteration 520 = 113.63808240609164
#
# Cost at iteration 521 = 113.61169350185732
#
# Cost at iteration 522 = 113.58531072885788
#
# Cost at iteration 523 = 113.55893408249331
#
# Cost at iteration 524 = 113.53256355816909
#
# Cost at iteration 525 = 113.50619915129609
#
# Cost at iteration 526 = 113.47984085729071
#
# Cost at iteration 527 = 113.45348867157476
#
# Cost at iteration 528 = 113.42714258957544
#
# Cost at iteration 529 = 113.4008026067255
#
# Cost at iteration 530 = 113.37446871846306
#
# Cost at iteration 531 = 113.34814092023163
#
# Cost at iteration 532 = 113.32181920748013
#
# Cost at iteration 533 = 113.29550357566298
#
# Cost at iteration 534 = 113.2691940202399
#
# Cost at iteration 535 = 113.2428905366761
#
# Cost at iteration 536 = 113.21659312044214
#
# Cost at iteration 537 = 113.19030176701393
#
# Cost at iteration 538 = 113.16401647187286
#
# Cost at iteration 539 = 113.1377372305056
#
# Cost at iteration 540 = 113.11146403840421
#
# Cost at iteration 541 = 113.08519689106623
#
# Cost at iteration 542 = 113.05893578399436
#
# Cost at iteration 543 = 113.03268071269683
#
# Cost at iteration 544 = 113.0064316726871
#
# Cost at iteration 545 = 112.98018865948409
#
# Cost at iteration 546 = 112.95395166861194
#
# Cost at iteration 547 = 112.92772069560016
#
# Cost at iteration 548 = 112.9014957359836
#
# Cost at iteration 549 = 112.87527678530246
#
# Cost at iteration 550 = 112.84906383910221
#
# Cost at iteration 551 = 112.82285689293363
#
# Cost at iteration 552 = 112.79665594235281
#
# Cost at iteration 553 = 112.77046098292115
#
# Cost at iteration 554 = 112.74427201020534
#
# Cost at iteration 555 = 112.71808901977735
#
# Cost at iteration 556 = 112.69191200721441
#
# Cost at iteration 557 = 112.6657409680991
#
# Cost at iteration 558 = 112.63957589801916
#
# Cost at iteration 559 = 112.61341679256769
#
# Cost at iteration 560 = 112.58726364734304
#
# Cost at iteration 561 = 112.5611164579487
#
# Cost at iteration 562 = 112.53497521999356
#
# Cost at iteration 563 = 112.50883992909168
#
# Cost at iteration 564 = 112.48271058086237
#
# Cost at iteration 565 = 112.45658717093012
#
# Cost at iteration 566 = 112.43046969492478
#
# Cost at iteration 567 = 112.40435814848126
#
# Cost at iteration 568 = 112.3782525272398
#
# Cost at iteration 569 = 112.3521528268458
#
# Cost at iteration 570 = 112.32605904294985
#
# Cost at iteration 571 = 112.29997117120779
#
# Cost at iteration 572 = 112.27388920728063
#
# Cost at iteration 573 = 112.24781314683456
#
# Cost at iteration 574 = 112.22174298554097
#
# Cost at iteration 575 = 112.1956787190764
#
# Cost at iteration 576 = 112.16962034312257
#
# Cost at iteration 577 = 112.14356785336639
#
# Cost at iteration 578 = 112.11752124549992
#
# Cost at iteration 579 = 112.09148051522041
#
# Cost at iteration 580 = 112.06544565823017
#
# Cost at iteration 581 = 112.03941667023672
#
# Cost at iteration 582 = 112.01339354695273
#
# Cost at iteration 583 = 111.98737628409593
#
# Cost at iteration 584 = 111.96136487738936
#
# Cost at iteration 585 = 111.93535932256093
#
# Cost at iteration 586 = 111.90935961534387
#
# Cost at iteration 587 = 111.88336575147639
#
# Cost at iteration 588 = 111.85737772670197
#
# Cost at iteration 589 = 111.831395536769
#
# Cost at iteration 590 = 111.80541917743109
#
# Cost at iteration 591 = 111.77944864444696
#
# Cost at iteration 592 = 111.75348393358031
#
# Cost at iteration 593 = 111.7275250406
#
# Cost at iteration 594 = 111.70157196127998
#
# Cost at iteration 595 = 111.67562469139922
#
# Cost at iteration 596 = 111.64968322674176
#
# Cost at iteration 597 = 111.62374756309679
#
# Cost at iteration 598 = 111.59781769625837
#
# Cost at iteration 599 = 111.57189362202588
#
# Cost at iteration 600 = 111.54597533620347
#
# Cost at iteration 601 = 111.52006283460047
#
# Cost at iteration 602 = 111.4941561130313
#
# Cost at iteration 603 = 111.46825516731526
#
# Cost at iteration 604 = 111.44235999327681
#
# Cost at iteration 605 = 111.41647058674538
#
# Cost at iteration 606 = 111.39058694355536
#
# Cost at iteration 607 = 111.36470905954626
#
# Cost at iteration 608 = 111.33883693056246
#
# Cost at iteration 609 = 111.31297055245348
#
# Cost at iteration 610 = 111.28710992107374
#
# Cost at iteration 611 = 111.26125503228269
#
# Cost at iteration 612 = 111.23540588194474
#
# Cost at iteration 613 = 111.2095624659293
#
# Cost at iteration 614 = 111.18372478011072
#
# Cost at iteration 615 = 111.15789282036839
#
# Cost at iteration 616 = 111.13206658258662
#
# Cost at iteration 617 = 111.10624606265462
#
# Cost at iteration 618 = 111.08043125646667
#
# Cost at iteration 619 = 111.05462215992188
#
# Cost at iteration 620 = 111.02881876892445
#
# Cost at iteration 621 = 111.00302107938334
#
# Cost at iteration 622 = 110.9772290872126
#
# Cost at iteration 623 = 110.95144278833114
#
# Cost at iteration 624 = 110.92566217866278
#
# Cost at iteration 625 = 110.89988725413629
#
# Cost at iteration 626 = 110.87411801068535
#
# Cost at iteration 627 = 110.84835444424851
#
# Cost at iteration 628 = 110.82259655076929
#
# Cost at iteration 629 = 110.79684432619607
#
# Cost at iteration 630 = 110.77109776648211
#
# Cost at iteration 631 = 110.74535686758563
#
# Cost at iteration 632 = 110.7196216254696
#
# Cost at iteration 633 = 110.693892036102
#
# Cost at iteration 634 = 110.66816809545561
#
# Cost at iteration 635 = 110.64244979950817
#
# Cost at iteration 636 = 110.61673714424214
#
# Cost at iteration 637 = 110.591030125645
#
# Cost at iteration 638 = 110.56532873970893
#
# Cost at iteration 639 = 110.53963298243107
#
# Cost at iteration 640 = 110.51394284981336
#
# Cost at iteration 641 = 110.48825833786262
#
# Cost at iteration 642 = 110.46257944259047
#
# Cost at iteration 643 = 110.43690616001328
#
# Cost at iteration 644 = 110.41123848615244
#
# Cost at iteration 645 = 110.38557641703404
#
# Cost at iteration 646 = 110.35991994868893
#
# Cost at iteration 647 = 110.33426907715285
#
# Cost at iteration 648 = 110.30862379846646
#
# Cost at iteration 649 = 110.28298410867492
#
# Cost at iteration 650 = 110.25735000382848
#
# Cost at iteration 651 = 110.231721479982
#
# Cost at iteration 652 = 110.20609853319529
#
# Cost at iteration 653 = 110.18048115953273
#
# Cost at iteration 654 = 110.15486935506368
#
# Cost at iteration 655 = 110.12926311586212
#
# Cost at iteration 656 = 110.10366243800692
#
# Cost at iteration 657 = 110.07806731758163
#
# Cost at iteration 658 = 110.05247775067457
#
# Cost at iteration 659 = 110.02689373337888
#
# Cost at iteration 660 = 110.00131526179239
#
# Cost at iteration 661 = 109.97574233201766
#
# Cost at iteration 662 = 109.95017494016201
#
# Cost at iteration 663 = 109.9246130823375
#
# Cost at iteration 664 = 109.89905675466096
#
# Cost at iteration 665 = 109.87350595325384
#
# Cost at iteration 666 = 109.84796067424247
#
# Cost at iteration 667 = 109.8224209137577
#
# Cost at iteration 668 = 109.79688666793523
#
# Cost at iteration 669 = 109.77135793291546
#
# Cost at iteration 670 = 109.74583470484346
#
# Cost at iteration 671 = 109.72031697986898
#
# Cost at iteration 672 = 109.69480475414649
#
# Cost at iteration 673 = 109.66929802383514
#
# Cost at iteration 674 = 109.64379678509879
#
# Cost at iteration 675 = 109.61830103410593
#
# Cost at iteration 676 = 109.59281076702975
#
# Cost at iteration 677 = 109.5673259800481
#
# Cost at iteration 678 = 109.54184666934356
#
# Cost at iteration 679 = 109.5163728311033
#
# Cost at iteration 680 = 109.49090446151911
#
# Cost at iteration 681 = 109.4654415567875
#
# Cost at iteration 682 = 109.43998411310967
#
# Cost at iteration 683 = 109.41453212669136
#
# Cost at iteration 684 = 109.38908559374302
#
# Cost at iteration 685 = 109.36364451047963
#
# Cost at iteration 686 = 109.33820887312098
#
# Cost at iteration 687 = 109.31277867789132
#
# Cost at iteration 688 = 109.28735392101956
#
# Cost at iteration 689 = 109.26193459873932
#
# Cost at iteration 690 = 109.23652070728868
#
# Cost at iteration 691 = 109.21111224291043
#
# Cost at iteration 692 = 109.18570920185192
#
# Cost at iteration 693 = 109.16031158036513
#
# Cost at iteration 694 = 109.13491937470663
#
# Cost at iteration 695 = 109.1095325811375
#
# Cost at iteration 696 = 109.08415119592354
#
# Cost at iteration 697 = 109.058775215335
#
# Cost at iteration 698 = 109.03340463564673
#
# Cost at iteration 699 = 109.00803945313828
#
# Cost at iteration 700 = 108.9826796640936
#
# Cost at iteration 701 = 108.95732526480124
#
# Cost at iteration 702 = 108.93197625155442
#
# Cost at iteration 703 = 108.90663262065077
#
# Cost at iteration 704 = 108.88129436839253
#
# Cost at iteration 705 = 108.85596149108648
#
# Cost at iteration 706 = 108.83063398504395
#
# Cost at iteration 707 = 108.80531184658078
#
# Cost at iteration 708 = 108.77999507201737
#
# Cost at iteration 709 = 108.75468365767861
#
# Cost at iteration 710 = 108.72937759989395
#
# Cost at iteration 711 = 108.70407689499734
#
# Cost at iteration 712 = 108.67878153932726
#
# Cost at iteration 713 = 108.65349152922664
#
# Cost at iteration 714 = 108.62820686104298
#
# Cost at iteration 715 = 108.60292753112824
#
# Cost at iteration 716 = 108.57765353583895
#
# Cost at iteration 717 = 108.55238487153602
#
# Cost at iteration 718 = 108.52712153458486
#
# Cost at iteration 719 = 108.50186352135553
#
# Cost at iteration 720 = 108.4766108282223
#
# Cost at iteration 721 = 108.45136345156419
#
# Cost at iteration 722 = 108.42612138776444
#
# Cost at iteration 723 = 108.40088463321091
#
# Cost at iteration 724 = 108.37565318429596
#
# Cost at iteration 725 = 108.3504270374162
#
# Cost at iteration 726 = 108.32520618897291
#
# Cost at iteration 727 = 108.29999063537171
#
# Cost at iteration 728 = 108.2747803730227
#
# Cost at iteration 729 = 108.24957539834038
#
# Cost at iteration 730 = 108.22437570774369
#
# Cost at iteration 731 = 108.19918129765607
#
# Cost at iteration 732 = 108.17399216450532
#
# Cost at iteration 733 = 108.1488083047237
#
# Cost at iteration 734 = 108.12362971474785
#
# Cost at iteration 735 = 108.09845639101881
#
# Cost at iteration 736 = 108.07328832998212
#
# Cost at iteration 737 = 108.04812552808765
#
# Cost at iteration 738 = 108.02296798178973
#
# Cost at iteration 739 = 107.99781568754702
#
# Cost at iteration 740 = 107.97266864182258
#
# Cost at iteration 741 = 107.94752684108391
#
# Cost at iteration 742 = 107.92239028180288
#
# Cost at iteration 743 = 107.89725896045569
#
# Cost at iteration 744 = 107.872132873523
#
# Cost at iteration 745 = 107.84701201748977
#
# Cost at iteration 746 = 107.82189638884537
#
# Cost at iteration 747 = 107.79678598408354
#
# Cost at iteration 748 = 107.77168079970231
#
# Cost at iteration 749 = 107.74658083220419
#
# Cost at iteration 750 = 107.72148607809588
# Cost at iteration 751 = 107.69639653388862
#
# Cost at iteration 752 = 107.6713121960978
#
# Cost at iteration 753 = 107.64623306124331
#
# Cost at iteration 754 = 107.62115912584926
#
# Cost at iteration 755 = 107.59609038644416
#
# Cost at iteration 756 = 107.57102683956084
#
# Cost at iteration 757 = 107.54596848173641
#
# Cost at iteration 758 = 107.52091530951229
#
# Cost at iteration 759 = 107.49586731943437
#
# Cost at iteration 760 = 107.47082450805263
#
# Cost at iteration 761 = 107.44578687192148
#
# Cost at iteration 762 = 107.42075440759963
#
# Cost at iteration 763 = 107.39572711165006
#
# Cost at iteration 764 = 107.37070498064007
#
# Cost at iteration 765 = 107.34568801114122
#
# Cost at iteration 766 = 107.3206761997294
#
# Cost at iteration 767 = 107.29566954298474
#
# Cost at iteration 768 = 107.27066803749166
#
# Cost at iteration 769 = 107.24567167983886
#
# Cost at iteration 770 = 107.22068046661936
#
# Cost at iteration 771 = 107.19569439443028
#
# Cost at iteration 772 = 107.17071345987324
#
# Cost at iteration 773 = 107.14573765955392
#
# Cost at iteration 774 = 107.12076699008239
#
# Cost at iteration 775 = 107.09580144807288
#
# Cost at iteration 776 = 107.07084103014391
#
# Cost at iteration 777 = 107.04588573291825
#
# Cost at iteration 778 = 107.02093555302282
#
# Cost at iteration 779 = 106.99599048708896
#
# Cost at iteration 780 = 106.97105053175203
#
# Cost at iteration 781 = 106.94611568365175
#
# Cost at iteration 782 = 106.92118593943205
#
# Cost at iteration 783 = 106.89626129574104
#
# Cost at iteration 784 = 106.87134174923102
#
# Cost at iteration 785 = 106.84642729655859
#
# Cost at iteration 786 = 106.82151793438452
#
# Cost at iteration 787 = 106.79661365937373
#
# Cost at iteration 788 = 106.7717144681954
#
# Cost at iteration 789 = 106.74682035752292
#
# Cost at iteration 790 = 106.72193132403382
#
# Cost at iteration 791 = 106.69704736440978
#
# Cost at iteration 792 = 106.67216847533682
#
# Cost at iteration 793 = 106.64729465350496
#
# Cost at iteration 794 = 106.62242589560856
#
# Cost at iteration 795 = 106.59756219834597
#
# Cost at iteration 796 = 106.57270355841986
#
# Cost at iteration 797 = 106.54784997253704
#
# Cost at iteration 798 = 106.52300143740841
#
# Cost at iteration 799 = 106.49815794974911
#
# Cost at iteration 800 = 106.47331950627837
#
# Cost at iteration 801 = 106.4484861037196
#
# Cost at iteration 802 = 106.42365773880032
#
# Cost at iteration 803 = 106.39883440825223
#
# Cost at iteration 804 = 106.37401610881123
#
# Cost at iteration 805 = 106.34920283721719
#
# Cost at iteration 806 = 106.32439459021424
#
# Cost at iteration 807 = 106.29959136455061
#
# Cost at iteration 808 = 106.27479315697859
#
# Cost at iteration 809 = 106.24999996425468
#
# Cost at iteration 810 = 106.22521178313946
#
# Cost at iteration 811 = 106.20042861039762
#
# Cost at iteration 812 = 106.1756504427979
#
# Cost at iteration 813 = 106.15087727711328
#
# Cost at iteration 814 = 106.12610911012071
#
# Cost at iteration 815 = 106.10134593860128
#
# Cost at iteration 816 = 106.07658775934019
#
# Cost at iteration 817 = 106.05183456912668
#
# Cost at iteration 818 = 106.02708636475417
#
# Cost at iteration 819 = 106.00234314302003
#
# Cost at iteration 820 = 105.97760490072584
#
# Cost at iteration 821 = 105.95287163467717
#
# Cost at iteration 822 = 105.92814334168365
#
# Cost at iteration 823 = 105.90342001855907
#
# Cost at iteration 824 = 105.87870166212116
#
# Cost at iteration 825 = 105.85398826919185
#
# Cost at iteration 826 = 105.82927983659694
#
# Cost at iteration 827 = 105.80457636116647
#
# Cost at iteration 828 = 105.77987783973438
#
# Cost at iteration 829 = 105.7551842691388
#
# Cost at iteration 830 = 105.73049564622174
#
# Cost at iteration 831 = 105.70581196782936
#
# Cost at iteration 832 = 105.6811332308118
#
# Cost at iteration 833 = 105.65645943202331
#
# Cost at iteration 834 = 105.63179056832205
#
# Cost at iteration 835 = 105.60712663657024
#
# Cost at iteration 836 = 105.5824676336342
#
# Cost at iteration 837 = 105.55781355638413
#
# Cost at iteration 838 = 105.53316440169438
#
# Cost at iteration 839 = 105.50852016644319
#
# Cost at iteration 840 = 105.48388084751289
#
# Cost at iteration 841 = 105.45924644178973
#
# Cost at iteration 842 = 105.43461694616404
#
# Cost at iteration 843 = 105.4099923575301
#
# Cost at iteration 844 = 105.38537267278613
#
# Cost at iteration 845 = 105.36075788883447
#
# Cost at iteration 846 = 105.33614800258135
#
# Cost at iteration 847 = 105.31154301093693
#
# Cost at iteration 848 = 105.28694291081545
#
# Cost at iteration 849 = 105.26234769913508
#
# Cost at iteration 850 = 105.23775737281797
#
# Cost at iteration 851 = 105.21317192879019
#
# Cost at iteration 852 = 105.1885913639818
#
# Cost at iteration 853 = 105.16401567532682
#
# Cost at iteration 854 = 105.1394448597633
#
# Cost at iteration 855 = 105.11487891423305
#
# Cost at iteration 856 = 105.09031783568201
#
# Cost at iteration 857 = 105.06576162105998
#
# Cost at iteration 858 = 105.04121026732071
#
# Cost at iteration 859 = 105.0166637714219
#
# Cost at iteration 860 = 104.99212213032516
#
# Cost at iteration 861 = 104.96758534099604
#
# Cost at iteration 862 = 104.94305340040404
#
# Cost at iteration 863 = 104.91852630552255
#
# Cost at iteration 864 = 104.89400405332886
#
# Cost at iteration 865 = 104.86948664080424
#
# Cost at iteration 866 = 104.84497406493384
#
# Cost at iteration 867 = 104.82046632270671
#
# Cost at iteration 868 = 104.79596341111578
#
# Cost at iteration 869 = 104.77146532715794
#
# Cost at iteration 870 = 104.74697206783394
#
# Cost at iteration 871 = 104.72248363014842
#
# Cost at iteration 872 = 104.69800001110997
#
# Cost at iteration 873 = 104.67352120773093
#
# Cost at iteration 874 = 104.64904721702774
#
# Cost at iteration 875 = 104.62457803602047
#
# Cost at iteration 876 = 104.60011366173329
#
# Cost at iteration 877 = 104.57565409119408
#
# Cost at iteration 878 = 104.55119932143471
#
# Cost at iteration 879 = 104.5267493494908
#
# Cost at iteration 880 = 104.50230417240196
#
# Cost at iteration 881 = 104.47786378721159
#
# Cost at iteration 882 = 104.4534281909669
#
# Cost at iteration 883 = 104.42899738071908
#
# Cost at iteration 884 = 104.40457135352305
#
# Cost at iteration 885 = 104.38015010643763
#
# Cost at iteration 886 = 104.35573363652549
#
# Cost at iteration 887 = 104.3313219408531
#
# Cost at iteration 888 = 104.30691501649079
#
# Cost at iteration 889 = 104.28251286051277
#
# Cost at iteration 890 = 104.25811546999698
#
# Cost at iteration 891 = 104.23372284202529
#
# Cost at iteration 892 = 104.20933497368331
#
# Cost at iteration 893 = 104.18495186206052
#
# Cost at iteration 894 = 104.16057350425021
#
# Cost at iteration 895 = 104.13619989734941
#
# Cost at iteration 896 = 104.11183103845909
#
# Cost at iteration 897 = 104.08746692468392
#
# Cost at iteration 898 = 104.06310755313241
#
# Cost at iteration 899 = 104.03875292091693
#
# Cost at iteration 900 = 104.01440302515347
#
# Cost at iteration 901 = 103.99005786296202
#
# Cost at iteration 902 = 103.96571743146622
#
# Cost at iteration 903 = 103.94138172779357
#
# Cost at iteration 904 = 103.91705074907534
#
# Cost at iteration 905 = 103.89272449244652
#
# Cost at iteration 906 = 103.86840295504595
#
# Cost at iteration 907 = 103.84408613401618
#
# Cost at iteration 908 = 103.81977402650364
#
# Cost at iteration 909 = 103.79546662965836
#
# Cost at iteration 910 = 103.7711639406343
#
# Cost at iteration 911 = 103.74686595658903
#
# Cost at iteration 912 = 103.722572674684
#
# Cost at iteration 913 = 103.69828409208435
#
# Cost at iteration 914 = 103.674000205959
#
# Cost at iteration 915 = 103.64972101348056
#
# Cost at iteration 916 = 103.62544651182546
#
# Cost at iteration 917 = 103.6011766981738
#
# Cost at iteration 918 = 103.57691156970947
#
# Cost at iteration 919 = 103.55265112362005
#
# Cost at iteration 920 = 103.52839535709693
#
# Cost at iteration 921 = 103.5041442673351
#
# Cost at iteration 922 = 103.47989785153344
#
# Cost at iteration 923 = 103.45565610689434
#
# Cost at iteration 924 = 103.4314190306241
#
# Cost at iteration 925 = 103.40718661993263
#
# Cost at iteration 926 = 103.38295887203361
#
# Cost at iteration 927 = 103.35873578414437
#
# Cost at iteration 928 = 103.33451735348596
#
# Cost at iteration 929 = 103.31030357728321
#
# Cost at iteration 930 = 103.28609445276447
#
# Cost at iteration 931 = 103.26188997716197
#
# Cost at iteration 932 = 103.23769014771159
#
# Cost at iteration 933 = 103.21349496165281
#
# Cost at iteration 934 = 103.18930441622886
#
# Cost at iteration 935 = 103.16511850868667
#
# Cost at iteration 936 = 103.14093723627678
#
# Cost at iteration 937 = 103.11676059625353
#
# Cost at iteration 938 = 103.09258858587481
#
# Cost at iteration 939 = 103.06842120240218
#
# Cost at iteration 940 = 103.04425844310099
#
# Cost at iteration 941 = 103.02010030524013
#
# Cost at iteration 942 = 102.99594678609222
#
# Cost at iteration 943 = 102.97179788293346
#
# Cost at iteration 944 = 102.94765359304384
#
# Cost at iteration 945 = 102.92351391370686
#
# Cost at iteration 946 = 102.89937884220974
#
# Cost at iteration 947 = 102.87524837584334
#
# Cost at iteration 948 = 102.85112251190215
#
# Cost at iteration 949 = 102.82700124768425
#
# Cost at iteration 950 = 102.80288458049148
#
# Cost at iteration 951 = 102.77877250762924
#
# Cost at iteration 952 = 102.75466502640649
#
# Cost at iteration 953 = 102.73056213413595
#
# Cost at iteration 954 = 102.70646382813385
#
# Cost at iteration 955 = 102.68237010572011
#
# Cost at iteration 956 = 102.65828096421825
#
# Cost at iteration 957 = 102.63419640095539
#
# Cost at iteration 958 = 102.61011641326229
#
# Cost at iteration 959 = 102.5860409984733
#
# Cost at iteration 960 = 102.56197015392631
#
# Cost at iteration 961 = 102.53790387696294
#
# Cost at iteration 962 = 102.51384216492826
#
# Cost at iteration 963 = 102.48978501517114
#
# Cost at iteration 964 = 102.46573242504385
#
# Cost at iteration 965 = 102.4416843919023
#
# Cost at iteration 966 = 102.41764091310608
#
# Cost at iteration 967 = 102.3936019860182
#
# Cost at iteration 968 = 102.36956760800541
#
# Cost at iteration 969 = 102.34553777643794
#
# Cost at iteration 970 = 102.32151248868959
# Cost at iteration 971 = 102.29749174213784
#
# Cost at iteration 972 = 102.27347553416355
#
# Cost at iteration 973 = 102.24946386215143
#
# Cost at iteration 974 = 102.2254567234894
#
# Cost at iteration 975 = 102.20145411556918
#
# Cost at iteration 976 = 102.17745603578604
#
# Cost at iteration 977 = 102.15346248153868
#
# Cost at iteration 978 = 102.12947345022945
#
# Cost at iteration 979 = 102.1054889392642
#
# Cost at iteration 980 = 102.08150894605235
#
# Cost at iteration 981 = 102.05753346800687
#
# Cost at iteration 982 = 102.03356250254419
#
# Cost at iteration 983 = 102.0095960470844
#
# Cost at iteration 984 = 101.98563409905101
#
# Cost at iteration 985 = 101.96167665587116
#
# Cost at iteration 986 = 101.93772371497543
#
# Cost at iteration 987 = 101.91377527379792
#
# Cost at iteration 988 = 101.88983132977637
#
# Cost at iteration 989 = 101.86589188035191
#
# Cost at iteration 990 = 101.84195692296923
#
# Cost at iteration 991 = 101.81802645507655
#
# Cost at iteration 992 = 101.79410047412553
#
# Cost at iteration 993 = 101.77017897757145
#
# Cost at iteration 994 = 101.746261962873
#
# Cost at iteration 995 = 101.72234942749243
#
# Cost at iteration 996 = 101.69844136889543
#
# Cost at iteration 997 = 101.6745377845512
#
# Cost at iteration 998 = 101.65063867193246
#
# Cost at iteration 999 = 101.62674402851542
#
# Cost at iteration 1000 = 101.60285385177974
#
# Cost at iteration 1001 = 101.57896813920857
#
# Cost at iteration 1002 = 101.55508688828856
#
# Cost at iteration 1003 = 101.53121009650985
#
# Cost at iteration 1004 = 101.50733776136599
#
# Cost at iteration 1005 = 101.48346988035404
#
# Cost at iteration 1006 = 101.45960645097458
#
# Cost at iteration 1007 = 101.4357474707316
#
# Cost at iteration 1008 = 101.4118929371325
#
# Cost at iteration 1009 = 101.38804284768824
#
# Cost at iteration 1010 = 101.3641971999132
#
# Cost at iteration 1011 = 101.34035599132521
#
# Cost at iteration 1012 = 101.31651921944552
#
# Cost at iteration 1013 = 101.2926868817989
#
# Cost at iteration 1014 = 101.26885897591352
#
# Cost at iteration 1015 = 101.24503549932092
#
# Cost at iteration 1016 = 101.22121644955628
#
# Cost at iteration 1017 = 101.19740182415799
#
# Cost at iteration 1018 = 101.17359162066803
#
# Cost at iteration 1019 = 101.14978583663175
#
# Cost at iteration 1020 = 101.1259844695979
#
# Cost at iteration 1021 = 101.10218751711874
#
# Cost at iteration 1022 = 101.0783949767499
#
# Cost at iteration 1023 = 101.05460684605043
#
# Cost at iteration 1024 = 101.03082312258277
#
# Cost at iteration 1025 = 101.00704380391286
#
# Cost at iteration 1026 = 100.98326888760995
#
# Cost at iteration 1027 = 100.9594983712468
#
# Cost at iteration 1028 = 100.93573225239945
#
# Cost at iteration 1029 = 100.91197052864746
#
# Cost at iteration 1030 = 100.88821319757372
#
# Cost at iteration 1031 = 100.86446025676462
#
# Cost at iteration 1032 = 100.8407117038098
#
# Cost at iteration 1033 = 100.81696753630236
#
# Cost at iteration 1034 = 100.79322775183881
#
# Cost at iteration 1035 = 100.76949234801901
#
# Cost at iteration 1036 = 100.74576132244627
#
# Cost at iteration 1037 = 100.72203467272718
#
# Cost at iteration 1038 = 100.69831239647174
#
# Cost at iteration 1039 = 100.6745944912934
#
# Cost at iteration 1040 = 100.65088095480888
#
# Cost at iteration 1041 = 100.62717178463839
#
# Cost at iteration 1042 = 100.60346697840536
#
# Cost at iteration 1043 = 100.57976653373669
#
# Cost at iteration 1044 = 100.55607044826259
#
# Cost at iteration 1045 = 100.53237871961667
#
# Cost at iteration 1046 = 100.50869134543589
#
# Cost at iteration 1047 = 100.48500832336052
#
# Cost at iteration 1048 = 100.46132965103423
#
# Cost at iteration 1049 = 100.437655326104
#
# Cost at iteration 1050 = 100.4139853462202
#
# Cost at iteration 1051 = 100.39031970903649
#
# Cost at iteration 1052 = 100.36665841220989
#
# Cost at iteration 1053 = 100.34300145340082
#
# Cost at iteration 1054 = 100.31934883027289
#
# Cost at iteration 1055 = 100.29570054049319
#
# Cost at iteration 1056 = 100.27205658173209
#
# Cost at iteration 1057 = 100.24841695166323
#
# Cost at iteration 1058 = 100.22478164796365
#
# Cost at iteration 1059 = 100.20115066831369
#
# Cost at iteration 1060 = 100.17752401039698
#
# Cost at iteration 1061 = 100.15390167190047
#
# Cost at iteration 1062 = 100.13028365051444
#
# Cost at iteration 1063 = 100.10666994393253
#
# Cost at iteration 1064 = 100.08306054985158
#
# Cost at iteration 1065 = 100.0594554659718
#
# Cost at iteration 1066 = 100.0358546899967
#
# Cost at iteration 1067 = 100.0122582196331
#
# Cost at iteration 1068 = 99.98866605259107
#
# Cost at iteration 1069 = 99.96507818658402
#
# Cost at iteration 1070 = 99.94149461932867
#
# Cost at iteration 1071 = 99.91791534854492
#
# Cost at iteration 1072 = 99.89434037195608
#
# Cost at iteration 1073 = 99.87076968728867
#
# Cost at iteration 1074 = 99.84720329227254
#
# Cost at iteration 1075 = 99.82364118464079
#
# Cost at iteration 1076 = 99.80008336212981
#
# Cost at iteration 1077 = 99.77652982247926
#
# Cost at iteration 1078 = 99.75298056343205
#
# Cost at iteration 1079 = 99.72943558273435
#
# Cost at iteration 1080 = 99.70589487813567
#
# Cost at iteration 1081 = 99.68235844738868
#
# Cost at iteration 1082 = 99.65882628824941
#
# Cost at iteration 1083 = 99.63529839847708
#
# Cost at iteration 1084 = 99.61177477583414
#
# Cost at iteration 1085 = 99.5882554180864
#
# Cost at iteration 1086 = 99.56474032300287
#
# Cost at iteration 1087 = 99.54122948835571
#
# Cost at iteration 1088 = 99.5177229119205
#
# Cost at iteration 1089 = 99.49422059147594
#
# Cost at iteration 1090 = 99.47072252480396
#
# Cost at iteration 1091 = 99.4472287096898
#
# Cost at iteration 1092 = 99.42373914392194
#
# Cost at iteration 1093 = 99.40025382529198
#
# Cost at iteration 1094 = 99.3767727515949
#
# Cost at iteration 1095 = 99.35329592062877
#
# Cost at iteration 1096 = 99.32982333019494
# ...
#
# Cost at iteration 1639 = 87.16240655582214
#
# Cost at iteration 1640 = 87.14099351117704
#
# Cost at iteration 1641 = 87.11958392866559
#
# Cost at iteration 1642 = 87.09817780753414
#
# Cost at iteration 1643 = 87.07677514703114
#
# Cost at iteration 1644 = 87.05537594640725
#
# Cost at iteration 1645 = 87.03398020491525
#
# Cost at iteration 1646 = 87.0125879218101
#
# Cost at iteration 1647 = 86.99119909634888
#
# Cost at iteration 1648 = 86.96981372779085
#
# Cost at iteration 1649 = 86.94843181539743
#
# Cost at iteration 1650 = 86.92705335843215
#
# Cost at iteration 1651 = 86.90567835616076
#
# Cost at iteration 1652 = 86.884306807851
#
# Cost at iteration 1653 = 86.86293871277297
#
# Cost at iteration 1654 = 86.84157407019872
#
# Cost at iteration 1655 = 86.82021287940255
#
# Cost at iteration 1656 = 86.79885513966089
#
# Cost at iteration 1657 = 86.77750085025221
#
# Cost at iteration 1658 = 86.75615001045725
#
# Cost at iteration 1659 = 86.73480261955882
#
# Cost at iteration 1660 = 86.71345867684188
#
# Cost at iteration 1661 = 86.6921181815935
#
# Cost at iteration 1662 = 86.67078113310285
#
# Cost at iteration 1663 = 86.64944753066128
#
# Cost at iteration 1664 = 86.6281173735623
#
# Cost at iteration 1665 = 86.60679066110146
#
# Cost at iteration 1666 = 86.58546739257652
#
# Cost at iteration 1667 = 86.56414756728722
#
# Cost at iteration 1668 = 86.54283118453561
#
# Cost at iteration 1669 = 86.52151824362572
#
# Cost at iteration 1670 = 86.50020874386372
#
# Cost at iteration 1671 = 86.47890268455801
#
# Cost at iteration 1672 = 86.45760006501888
#
# Cost at iteration 1673 = 86.43630088455895
#
# Cost at iteration 1674 = 86.41500514249284
#
# Cost at iteration 1675 = 86.39371283813732
#
# Cost at iteration 1676 = 86.37242397081124
#
# Cost at iteration 1677 = 86.35113853983559
#
# Cost at iteration 1678 = 86.32985654453341
#
# Cost at iteration 1679 = 86.30857798422986
#
# Cost at iteration 1680 = 86.2873028582523
# Cost at iteration 1681 = 86.26603116593007
#
# Cost at iteration 1682 = 86.24476290659464
#
# Cost at iteration 1683 = 86.2234980795796
#
# Cost at iteration 1684 = 86.20223668422061
#
# Cost at iteration 1685 = 86.18097871985549
#
# Cost at iteration 1686 = 86.15972418582402
#
# Cost at iteration 1687 = 86.13847308146819
#
# Cost at iteration 1688 = 86.11722540613206
#
# Cost at iteration 1689 = 86.09598115916174
#
# Cost at iteration 1690 = 86.07474033990546
#
# Cost at iteration 1691 = 86.05350294771351
#
# Cost at iteration 1692 = 86.03226898193827
#
# Cost at iteration 1693 = 86.01103844193423
#
# Cost at iteration 1694 = 85.98981132705794
#
# Cost at iteration 1695 = 85.968587636668
#
# Cost at iteration 1696 = 85.94736737012515
#
# Cost at iteration 1697 = 85.92615052679216
#
# Cost at iteration 1698 = 85.90493710603387
#
# Cost at iteration 1699 = 85.88372710721723
#
# Cost at iteration 1700 = 85.86252052971128
#
# Cost at iteration 1701 = 85.84131737288699
#
# Cost at iteration 1702 = 85.82011763611759
#
# Cost at iteration 1703 = 85.79892131877824
#
# Cost at iteration 1704 = 85.77772842024623
#
# Cost at iteration 1705 = 85.75653893990092
#
# Cost at iteration 1706 = 85.73535287712367
#
# Cost at iteration 1707 = 85.71417023129794
#
# Cost at iteration 1708 = 85.6929910018093
#
# Cost at iteration 1709 = 85.67181518804529
#
# Cost at iteration 1710 = 85.65064278939553
#
# Cost at iteration 1711 = 85.62947380525178
#
# Cost at iteration 1712 = 85.60830823500767
#
# Cost at iteration 1713 = 85.5871460780591
#
# Cost at iteration 1714 = 85.56598733380388
#
# Cost at iteration 1715 = 85.54483200164186
#
# Cost at iteration 1716 = 85.52368008097508
#
# Cost at iteration 1717 = 85.50253157120743
#
# Cost at iteration 1718 = 85.481386471745
#
# Cost at iteration 1719 = 85.46024478199583
#
# Cost at iteration 1720 = 85.43910650137006
#
# Cost at iteration 1721 = 85.41797162927983
#
# Cost at iteration 1722 = 85.39684016513937
#
# Cost at iteration 1723 = 85.37571210836485
#
# Cost at iteration 1724 = 85.35458745837462
#
# Cost at iteration 1725 = 85.3334662145889
#
# Cost at iteration 1726 = 85.31234837643007
#
# Cost at iteration 1727 = 85.29123394332251
#
# Cost at iteration 1728 = 85.27012291469252
#
# Cost at iteration 1729 = 85.24901528996865
#
# Cost at iteration 1730 = 85.22791106858125
#
# Cost at iteration 1731 = 85.20681024996284
#
# Cost at iteration 1732 = 85.18571283354791
#
# Cost at iteration 1733 = 85.16461881877296
#
# Cost at iteration 1734 = 85.14352820507655
#
# Cost at iteration 1735 = 85.12244099189924
#
# Cost at iteration 1736 = 85.10135717868361
#
# Cost at iteration 1737 = 85.08027676487418
#
# Cost at iteration 1738 = 85.05919974991765
#
# Cost at iteration 1739 = 85.0381261332626
#
# Cost at iteration 1740 = 85.01705591435964
#
# Cost at iteration 1741 = 84.99598909266142
#
# Cost at iteration 1742 = 84.97492566762259
#
# Cost at iteration 1743 = 84.95386563869982
#
# Cost at iteration 1744 = 84.93280900535179
#
# Cost at iteration 1745 = 84.91175576703908
#
# Cost at iteration 1746 = 84.89070592322444
#
# Cost at iteration 1747 = 84.86965947337251
#
# Cost at iteration 1748 = 84.84861641694994
#
# Cost at iteration 1749 = 84.8275767534254
#
# Cost at iteration 1750 = 84.80654048226958
#
# Cost at iteration 1751 = 84.78550760295508
#
# Cost at iteration 1752 = 84.76447811495662
#
# Cost at iteration 1753 = 84.74345201775081
#
# Cost at iteration 1754 = 84.72242931081628
#
# Cost at iteration 1755 = 84.70140999363365
#
# Cost at iteration 1756 = 84.6803940656855
#
# Cost at iteration 1757 = 84.65938152645649
#
# Cost at iteration 1758 = 84.63837237543315
#
# Cost at iteration 1759 = 84.61736661210405
#
# Cost at iteration 1760 = 84.59636423595975
#
# Cost at iteration 1761 = 84.57536524649278
#
# Cost at iteration 1762 = 84.5543696431976
#
# Cost at iteration 1763 = 84.53337742557076
#
# Cost at iteration 1764 = 84.51238859311067
#
# Cost at iteration 1765 = 84.49140314531773
#
# Cost at iteration 1766 = 84.47042108169443
#
# Cost at iteration 1767 = 84.44944240174507
#
# Cost at iteration 1768 = 84.42846710497601
#
# Cost at iteration 1769 = 84.40749519089559
#
# Cost at iteration 1770 = 84.38652665901402
#
# Cost at iteration 1771 = 84.36556150884363
#
# Cost at iteration 1772 = 84.34459973989858
#
# Cost at iteration 1773 = 84.32364135169504
#
# Cost at iteration 1774 = 84.30268634375119
#
# Cost at iteration 1775 = 84.28173471558705
#
# Cost at iteration 1776 = 84.2607864667247
#
# Cost at iteration 1777 = 84.23984159668817
#
# Cost at iteration 1778 = 84.21890010500337
#
# Cost at iteration 1779 = 84.19796199119826
#
# Cost at iteration 1780 = 84.17702725480265
#
# Cost at iteration 1781 = 84.1560958953484
#
# Cost at iteration 1782 = 84.13516791236927
#
# Cost at iteration 1783 = 84.11424330540098
#
# Cost at iteration 1784 = 84.09332207398116
#
# Cost at iteration 1785 = 84.07240421764942
#
# Cost at iteration 1786 = 84.05148973594733
#
# Cost at iteration 1787 = 84.03057862841835
#
# Cost at iteration 1788 = 84.00967089460791
#
# Cost at iteration 1789 = 83.9887665340634
#
# Cost at iteration 1790 = 83.96786554633412
#
# Cost at iteration 1791 = 83.94696793097128
#
# Cost at iteration 1792 = 83.92607368752809
#
# Cost at iteration 1793 = 83.90518281555963
#
# Cost at iteration 1794 = 83.88429531462295
#
# Cost at iteration 1795 = 83.86341118427701
#
# Cost at iteration 1796 = 83.84253042408274
#
# Cost at iteration 1797 = 83.82165303360293
#
# Cost at iteration 1798 = 83.80077901240229
#
# Cost at iteration 1799 = 83.77990836004759
#
# Cost at iteration 1800 = 83.75904107610732
#
# Cost at iteration 1801 = 83.7381771601521
#
# Cost at iteration 1802 = 83.7173166117543
#
# Cost at iteration 1803 = 83.69645943048828
#
# Cost at iteration 1804 = 83.67560561593032
#
# Cost at iteration 1805 = 83.65475516765862
#
# Cost at iteration 1806 = 83.63390808525324
#
# Cost at iteration 1807 = 83.61306436829622
#
# Cost at iteration 1808 = 83.5922240163715
#
# Cost at iteration 1809 = 83.57138702906487
#
# Cost at iteration 1810 = 83.5505534059641
#
# Cost at iteration 1811 = 83.52972314665882
#
# Cost at iteration 1812 = 83.50889625074058
#
# Cost at iteration 1813 = 83.48807271780288
#
# Cost at iteration 1814 = 83.46725254744099
#
# Cost at iteration 1815 = 83.44643573925222
#
# Cost at iteration 1816 = 83.42562229283577
#
# Cost at iteration 1817 = 83.4048122077926
#
# Cost at iteration 1818 = 83.38400548372572
#
# Cost at iteration 1819 = 83.36320212023992
#
# Cost at iteration 1820 = 83.34240211694203
#
# Cost at iteration 1821 = 83.32160547344057
#
# Cost at iteration 1822 = 83.30081218934615
#
# Cost at iteration 1823 = 83.28002226427112
#
# Cost at iteration 1824 = 83.25923569782982
#
# Cost at iteration 1825 = 83.23845248963838
#
# Cost at iteration 1826 = 83.21767263931493
#
# Cost at iteration 1827 = 83.19689614647935
#
# Cost at iteration 1828 = 83.17612301075351
#
# Cost at iteration 1829 = 83.15535323176111
#
# Cost at iteration 1830 = 83.13458680912774
#
# Cost at iteration 1831 = 83.11382374248089
#
# Cost at iteration 1832 = 83.09306403144984
#
# Cost at iteration 1833 = 83.07230767566588
#
# Cost at iteration 1834 = 83.05155467476204
#
# Cost at iteration 1835 = 83.03080502837332
#
# Cost at iteration 1836 = 83.01005873613651
#
# Cost at iteration 1837 = 82.98931579769034
#
# Cost at iteration 1838 = 82.96857621267536
#
# Cost at iteration 1839 = 82.94783998073402
#
# Cost at iteration 1840 = 82.92710710151057
#
# Cost at iteration 1841 = 82.9063775746512
#
# Cost at iteration 1842 = 82.88565139980392
#
# Cost at iteration 1843 = 82.86492857661864
#
# Cost at iteration 1844 = 82.84420910474702
#
# Cost at iteration 1845 = 82.82349298384273
#
# Cost at iteration 1846 = 82.80278021356116
#
# Cost at iteration 1847 = 82.78207079355964
#
# Cost at iteration 1848 = 82.76136472349734
#
# Cost at iteration 1849 = 82.74066200303521
#
# Cost at iteration 1850 = 82.71996263183614
#
# Cost at iteration 1851 = 82.69926660956483
#
# Cost at iteration 1852 = 82.67857393588783
#
# Cost at iteration 1853 = 82.65788461047354
#
# Cost at iteration 1854 = 82.63719863299215
#
# Cost at iteration 1855 = 82.6165160031158
#
# Cost at iteration 1856 = 82.59583672051839
#
# Cost at iteration 1857 = 82.57516078487565
#
# Cost at iteration 1858 = 82.55448819586516
#
# Cost at iteration 1859 = 82.53381895316646
#
# Cost at iteration 1860 = 82.51315305646072
#
# Cost at iteration 1861 = 82.49249050543106
#
# Cost at iteration 1862 = 82.47183129976241
#
# Cost at iteration 1863 = 82.45117543914155
#
# Cost at iteration 1864 = 82.43052292325706
#
# Cost at iteration 1865 = 82.40987375179938
#
# Cost at iteration 1866 = 82.38922792446076
#
# Cost at iteration 1867 = 82.36858544093522
#
# Cost at iteration 1868 = 82.34794630091866
#
# Cost at iteration 1869 = 82.32731050410887
#
# Cost at iteration 1870 = 82.30667805020532
#
# Cost at iteration 1871 = 82.28604893890939
#
# Cost at iteration 1872 = 82.26542316992425
#
# Cost at iteration 1873 = 82.24480074295485
#
# Cost at iteration 1874 = 82.22418165770803
#
# Cost at iteration 1875 = 82.2035659138924
#
# Cost at iteration 1876 = 82.18295351121843
#
# Cost at iteration 1877 = 82.16234444939828
#
# Cost at iteration 1878 = 82.14173872814602
#
# Cost at iteration 1879 = 82.12113634717754
#
# Cost at iteration 1880 = 82.10053730621047
#
# Cost at iteration 1881 = 82.0799416049643
#
# Cost at iteration 1882 = 82.05934924316021
#
# Cost at iteration 1883 = 82.03876022052138
#
# Cost at iteration 1884 = 82.01817453677263
#
# Cost at iteration 1885 = 81.99759219164063
#
# Cost at iteration 1886 = 81.97701318485383
#
# Cost at iteration 1887 = 81.95643751614247
#
# Cost at iteration 1888 = 81.9358651852387
#
# Cost at iteration 1889 = 81.91529619187627
#
# Cost at iteration 1890 = 81.89473053579084
#
# Cost at iteration 1891 = 81.87416821671984
#
# Cost at iteration 1892 = 81.85360923440247
#
# Cost at iteration 1893 = 81.83305358857982
#
# Cost at iteration 1894 = 81.81250127899457
#
# Cost at iteration 1895 = 81.79195230539135
#
# Cost at iteration 1896 = 81.7714066675165
#
# Cost at iteration 1897 = 81.75086436511815
#
# Cost at iteration 1898 = 81.73032539794623
#
# Cost at iteration 1899 = 81.70978976575242
#
# Cost at iteration 1900 = 81.6892574682902
#
# Cost at iteration 1901 = 81.6687285053148
#
# Cost at iteration 1902 = 81.64820287658328
#
# Cost at iteration 1903 = 81.6276805818544
#
# Cost at iteration 1904 = 81.60716162088873
#
# Cost at iteration 1905 = 81.58664599344861
#
# Cost at iteration 1906 = 81.56613369929813
#
# Cost at iteration 1907 = 81.54562473820316
#
# Cost at iteration 1908 = 81.52511910993135
#
# Cost at iteration 1909 = 81.5046168142521
#
# Cost at iteration 1910 = 81.48411785093653
#
# Cost at iteration 1911 = 81.46362221975762
#
# Cost at iteration 1912 = 81.44312992048998
#
# Cost at iteration 1913 = 81.42264095291011
#
# Cost at iteration 1914 = 81.40215531679621
#
# Cost at iteration 1915 = 81.38167301192816
#
# Cost at iteration 1916 = 81.36119403808773
#
# Cost at iteration 1917 = 81.34071839505836
#
# Cost at iteration 1918 = 81.3202460826252
#
# Cost at iteration 1919 = 81.29977710057531
#
# Cost at iteration 1920 = 81.27931144869731
#
# Cost at iteration 1921 = 81.25884912678168
#
# Cost at iteration 1922 = 81.23839013462063
#
# Cost at iteration 1923 = 81.21793447200807
#
# Cost at iteration 1924 = 81.19748213873972
#
# Cost at iteration 1925 = 81.17703313461297
#
# Cost at iteration 1926 = 81.15658745942696
#
# Cost at iteration 1927 = 81.13614511298265
#
# Cost at iteration 1928 = 81.11570609508263
#
# Cost at iteration 1929 = 81.09527040553127
#
# Cost at iteration 1930 = 81.07483804413472
#
# Cost at iteration 1931 = 81.05440901070075
# Cost at iteration 1932 = 81.03398330503897
#
# Cost at iteration 1933 = 81.01356092696068
#
# Cost at iteration 1934 = 80.99314187627887
#
# Cost at iteration 1935 = 80.97272615280832
#
# Cost at iteration 1936 = 80.95231375636548
#
# Cost at iteration 1937 = 80.93190468676858
#
# Cost at iteration 1938 = 80.9114989438375
#
# Cost at iteration 1939 = 80.89109652739393
#
# Cost at iteration 1940 = 80.87069743726114
#
# Cost at iteration 1941 = 80.85030167326433
#
# Cost at iteration 1942 = 80.82990923523018
#
# Cost at iteration 1943 = 80.80952012298728
#
# Cost at iteration 1944 = 80.78913433636579
#
# Cost at iteration 1945 = 80.76875187519768
#
# Cost at iteration 1946 = 80.74837273931657
#
# Cost at iteration 1947 = 80.72799692855781
#
# Cost at iteration 1948 = 80.70762444275849
#
# Cost at iteration 1949 = 80.68725528175733
#
# Cost at iteration 1950 = 80.66688944539486
#
# Cost at iteration 1951 = 80.64652693351321
#
# Cost at iteration 1952 = 80.62616774595625
#
# Cost at iteration 1953 = 80.6058118825696
#
# Cost at iteration 1954 = 80.58545934320047
#
# Cost at iteration 1955 = 80.56511012769786
#
# Cost at iteration 1956 = 80.54476423591245
#
# Cost at iteration 1957 = 80.52442166769661
#
# Cost at iteration 1958 = 80.50408242290435
#
# Cost at iteration 1959 = 80.48374650139144
#
# Cost at iteration 1960 = 80.46341390301534
#
# Cost at iteration 1961 = 80.44308462763513
#
# Cost at iteration 1962 = 80.42275867511165
#
# Cost at iteration 1963 = 80.40243604530738
#
# Cost at iteration 1964 = 80.38211673808655
#
# Cost at iteration 1965 = 80.36180075331498
#
# Cost at iteration 1966 = 80.3414880908602
#
# Cost at iteration 1967 = 80.32117875059147
#
# Cost at iteration 1968 = 80.3008727323797
#
# Cost at iteration 1969 = 80.28057003609747
#
# Cost at iteration 1970 = 80.26027066161903
#
# Cost at iteration 1971 = 80.23997460882029
#
# Cost at iteration 1972 = 80.21968187757892
#
# Cost at iteration 1973 = 80.1993924677741
#
# Cost at iteration 1974 = 80.17910637928685
#
# Cost at iteration 1975 = 80.15882361199978
#
# Cost at iteration 1976 = 80.13854416579716
#
# Cost at iteration 1977 = 80.1182680405649
#
# Cost at iteration 1978 = 80.09799523619067
#
# Cost at iteration 1979 = 80.07772575256371
#
# Cost at iteration 1980 = 80.057459589575
#
# Cost at iteration 1981 = 80.0371967471171
#
# Cost at iteration 1982 = 80.01693722508425
#
# Cost at iteration 1983 = 79.99668102337239
#
# Cost at iteration 1984 = 79.97642814187907
#
# Cost at iteration 1985 = 79.9561785805035
#
# Cost at iteration 1986 = 79.9359323391466
#
# Cost at iteration 1987 = 79.91568941771085
#
# Cost at iteration 1988 = 79.89544981610044
#
# Cost at iteration 1989 = 79.87521353422119
#
# Cost at iteration 1990 = 79.85498057198058
#
# Cost at iteration 1991 = 79.83475092928768
#
# Cost at iteration 1992 = 79.81452460605333
#
# Cost at iteration 1993 = 79.79430160218988
#
# Cost at iteration 1994 = 79.77408191761135
#
# Cost at iteration 1995 = 79.75386555223346
#
# Cost at iteration 1996 = 79.73365250597351
#
# Cost at iteration 1997 = 79.71344277875049
#
# Cost at iteration 1998 = 79.69323637048494
#
# Cost at iteration 1999 = 79.67303328109912
#
# Cost at iteration 2000 = 79.65283351051693
#
# Root Mean Squared Error on Training Data = 12.620034632176234
# Root Mean Squared Error on Test Data = 12.745482848459234
